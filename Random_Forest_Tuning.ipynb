# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV, train_test_split, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('ML_train.csv')
test = pd.read_csv('ML_test.csv')

# %%
train.head()
# Out:
#    Unnamed: 0                                               Text  Sentiment
# 0           0  movie is funny suitable age is definitely fami...          6
# 1           1  old commercial blank audio cassette tag line w...          7
# 2           2  cinemascope color cinematography leon shamroy ...          4
# 3           3  get film possible will find really good perfor...          6
# 4           4  soundtrack is bit dated story is relevant yous...          6

# %%
train = train.drop(columns=['Unnamed: 0'])
train.head()
# Out:
#                                                 Text  Sentiment
# 0  movie is funny suitable age is definitely fami...          6
# 1  old commercial blank audio cassette tag line w...          7
# 2  cinemascope color cinematography leon shamroy ...          4
# 3  get film possible will find really good perfor...          6
# 4  soundtrack is bit dated story is relevant yous...          6

# %%
trial_train = train.copy()
trial_train.head()
# Out:
#                                                 Text  Sentiment
# 0  movie is funny suitable age is definitely fami...          6
# 1  old commercial blank audio cassette tag line w...          7
# 2  cinemascope color cinematography leon shamroy ...          4
# 3  get film possible will find really good perfor...          6
# 4  soundtrack is bit dated story is relevant yous...          6

# %%
def good_bad(row):
  if row > 4:
    return 1
  else:
    return 0

# %%
trial_train['Good'] = trial_train['Sentiment'].apply(good_bad)
trial_train.head()
# Out:
#                                                 Text  Sentiment  Good
# 0  movie is funny suitable age is definitely fami...          6     1
# 1  old commercial blank audio cassette tag line w...          7     1
# 2  cinemascope color cinematography leon shamroy ...          4     0
# 3  get film possible will find really good perfor...          6     1
# 4  soundtrack is bit dated story is relevant yous...          6     1

# %%
class2_X_train = trial_train['Text']
class2_y_train = trial_train['Good']

# %%
trial_test = test.copy()
trial_test.head()
# Out:
#    Unnamed: 0                                               Text  Sentiment
# 0           0  would highly recommend seeing movie viewing wi...          1
# 1           1  see everyone love film much true doe have good...          1
# 2           2  damn thought would seen bad western cannot top...          1
# 3           3  well certainly stunned believe someone made an...          1
# 4           4  jefferey dahmer wa one sick guy is much say al...          1

# %%
trial_test['Good'] = trial_test['Sentiment'].apply(good_bad)
trial_test.head()
# Out:
#    Unnamed: 0                                               Text  Sentiment  \
# 0           0  would highly recommend seeing movie viewing wi...          1
# 1           1  see everyone love film much true doe have good...          1
# 2           2  damn thought would seen bad western cannot top...          1
# 3           3  well certainly stunned believe someone made an...          1
# 4           4  jefferey dahmer wa one sick guy is much say al...          1
#
#    Good
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
class2_X_test = trial_test['Text']
class2_y_test = trial_test['Good']

# %% [markdown]
# # Vectorization

# %% [markdown]
# BOW Vectorizer

# %%
bow_vectorizer = CountVectorizer()
bow_vectorizer.fit(class2_X_train)

class2_bow_X_train = bow_vectorizer.transform(class2_X_train)
class2_bow_X_test = bow_vectorizer.transform(class2_X_test)

# %% [markdown]
# TF-IDF

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_vectorizer.fit(class2_X_train)

class2_tfidf_X_train = tfidf_vectorizer.transform(class2_X_train)
class2_tfidf_X_test = tfidf_vectorizer.transform(class2_X_test)

# %% [markdown]
# # Tuning Random Forest with BOW

# %%
param_grid = {
    'n_estimators': [50, 100, 150, 200, 500, 1000],
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_depth': [20, 30, 50, 75, 100],
    'min_samples_split': [10, 25, 50, 100, 150, 200, 400],
    'min_samples_leaf': [25, 50, 100]
}

# %%
rf_model = RandomForestClassifier(random_state = 42, n_jobs = -1)
clf = RandomizedSearchCV(rf_model, param_distributions=param_grid, cv=3, verbose=4, scoring='accuracy', random_state=42, n_iter=20)

# %%
best_clf = clf.fit(class2_bow_X_train, class2_y_train)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV 1/3] END criterion=entropy, max_depth=100, min_samples_leaf=100, min_samples_split=200, n_estimators=100;, score=0.846 total time=  19.4s
# [CV 2/3] END criterion=entropy, max_depth=100, min_samples_leaf=100, min_samples_split=200, n_estimators=100;, score=0.837 total time=  17.7s
# [CV 3/3] END criterion=entropy, max_depth=100, min_samples_leaf=100, min_samples_split=200, n_estimators=100;, score=0.808 total time=   4.4s
# [CV 1/3] END criterion=entropy, max_depth=75, min_samples_leaf=50, min_samples_split=10, n_estimators=500;, score=0.863 total time= 1.8min
# [CV 2/3] END criterion=entropy, max_depth=75, min_samples_leaf=50, min_samples_split=10, n_estimators=500;, score=0.859 total time= 2.0min
# [CV 3/3] END criterion=entropy, max_depth=75, min_samples_leaf=50, min_samples_split=10, n_estimators=500;, score=0.831 total time=  31.2s
# [CV 1/3] END criterion=log_loss, max_depth=75, min_samples_leaf=100, min_samples_split=100, n_estimators=1000;, score=0.857 total time= 2.9min
# [CV 2/3] END criterion=log_loss, max_depth=75, min_samples_leaf=100, min_samples_split=100, n_estimators=1000;, score=0.849 total time= 2.9min
# [CV 3/3] END criterion=log_loss, max_depth=75, min_samples_leaf=100, min_samples_split=100, n_estimators=1000;, score=0.816 total time=  35.5s
# [CV 1/3] END criterion=log_loss, max_depth=100, min_samples_leaf=25, min_samples_split=100, n_estimators=200;, score=0.870 total time=  51.2s
# [CV 2/3] END criterion=log_loss, max_depth=100, min_samples_leaf=25, min_samples_split=100, n_estimators=200;, score=0.864 total time= 1.0min
# [CV 3/3] END criterion=log_loss, max_depth=100, min_samples_leaf=25, min_samples_split=100, n_estimators=200;, score=0.842 total time=  18.3s
# [CV 1/3] END criterion=log_loss, max_depth=30, min_samples_leaf=50, min_samples_split=200, n_estimators=200;, score=0.857 total time=  44.1s
# [CV 2/3] END criterion=log_loss, max_depth=30, min_samples_leaf=50, min_samples_split=200, n_estimators=200;, score=0.852 total time=  45.8s
# [CV 3/3] END criterion=log_loss, max_depth=30, min_samples_leaf=50, min_samples_split=200, n_estimators=200;, score=0.825 total time=  14.0s
# [CV 1/3] END criterion=log_loss, max_depth=75, min_samples_leaf=100, min_samples_split=25, n_estimators=50;, score=0.834 total time=  10.8s
# [CV 2/3] END criterion=log_loss, max_depth=75, min_samples_leaf=100, min_samples_split=25, n_estimators=50;, score=0.829 total time=  11.3s
# [CV 3/3] END criterion=log_loss, max_depth=75, min_samples_leaf=100, min_samples_split=25, n_estimators=50;, score=0.797 total time=   2.9s
# [CV 1/3] END criterion=gini, max_depth=100, min_samples_leaf=100, min_samples_split=25, n_estimators=150;, score=0.851 total time=  29.6s
# [CV 2/3] END criterion=gini, max_depth=100, min_samples_leaf=100, min_samples_split=25, n_estimators=150;, score=0.841 total time=  30.7s
# [CV 3/3] END criterion=gini, max_depth=100, min_samples_leaf=100, min_samples_split=25, n_estimators=150;, score=0.806 total time=  10.0s
# [CV 1/3] END criterion=log_loss, max_depth=100, min_samples_leaf=50, min_samples_split=25, n_estimators=50;, score=0.847 total time=  11.3s
# [CV 2/3] END criterion=log_loss, max_depth=100, min_samples_leaf=50, min_samples_split=25, n_estimators=50;, score=0.846 total time=  11.5s
# [CV 3/3] END criterion=log_loss, max_depth=100, min_samples_leaf=50, min_samples_split=25, n_estimators=50;, score=0.812 total time=   2.3s
# [CV 1/3] END criterion=entropy, max_depth=30, min_samples_leaf=100, min_samples_split=100, n_estimators=100;, score=0.845 total time=  14.7s
# [CV 2/3] END criterion=entropy, max_depth=30, min_samples_leaf=100, min_samples_split=100, n_estimators=100;, score=0.837 total time=  15.1s
# [CV 3/3] END criterion=entropy, max_depth=30, min_samples_leaf=100, min_samples_split=100, n_estimators=100;, score=0.806 total time=   3.4s
# [CV 1/3] END criterion=gini, max_depth=30, min_samples_leaf=100, min_samples_split=10, n_estimators=150;, score=0.851 total time=  22.1s
# [CV 2/3] END criterion=gini, max_depth=30, min_samples_leaf=100, min_samples_split=10, n_estimators=150;, score=0.842 total time=  22.6s
# [CV 3/3] END criterion=gini, max_depth=30, min_samples_leaf=100, min_samples_split=10, n_estimators=150;, score=0.806 total time=   5.1s
# [CV 1/3] END criterion=log_loss, max_depth=20, min_samples_leaf=50, min_samples_split=200, n_estimators=150;, score=0.851 total time=  20.2s
# [CV 2/3] END criterion=log_loss, max_depth=20, min_samples_leaf=50, min_samples_split=200, n_estimators=150;, score=0.844 total time=  21.2s
# [CV 3/3] END criterion=log_loss, max_depth=20, min_samples_leaf=50, min_samples_split=200, n_estimators=150;, score=0.819 total time=   5.0s
# [CV 1/3] END criterion=entropy, max_depth=20, min_samples_leaf=100, min_samples_split=25, n_estimators=100;, score=0.844 total time=  12.3s
# [CV 2/3] END criterion=entropy, max_depth=20, min_samples_leaf=100, min_samples_split=25, n_estimators=100;, score=0.832 total time=  13.1s
# [CV 3/3] END criterion=entropy, max_depth=20, min_samples_leaf=100, min_samples_split=25, n_estimators=100;, score=0.802 total time=   4.4s
# [CV 1/3] END criterion=gini, max_depth=50, min_samples_leaf=100, min_samples_split=50, n_estimators=500;, score=0.855 total time= 1.3min
# [CV 2/3] END criterion=gini, max_depth=50, min_samples_leaf=100, min_samples_split=50, n_estimators=500;, score=0.848 total time= 1.3min
# [CV 3/3] END criterion=gini, max_depth=50, min_samples_leaf=100, min_samples_split=50, n_estimators=500;, score=0.814 total time=  18.2s
# [CV 1/3] END criterion=gini, max_depth=100, min_samples_leaf=50, min_samples_split=200, n_estimators=50;, score=0.846 total time=  10.7s
# [CV 2/3] END criterion=gini, max_depth=100, min_samples_leaf=50, min_samples_split=200, n_estimators=50;, score=0.846 total time=  11.0s
# [CV 3/3] END criterion=gini, max_depth=100, min_samples_leaf=50, min_samples_split=200, n_estimators=50;, score=0.804 total time=   2.2s
# [CV 1/3] END criterion=log_loss, max_depth=100, min_samples_leaf=50, min_samples_split=100, n_estimators=50;, score=0.847 total time=  10.8s
# [CV 2/3] END criterion=log_loss, max_depth=100, min_samples_leaf=50, min_samples_split=100, n_estimators=50;, score=0.846 total time=  11.3s
# [CV 3/3] END criterion=log_loss, max_depth=100, min_samples_leaf=50, min_samples_split=100, n_estimators=50;, score=0.812 total time=   2.3s
# [CV 1/3] END criterion=gini, max_depth=30, min_samples_leaf=50, min_samples_split=100, n_estimators=150;, score=0.856 total time=  26.3s
# [CV 2/3] END criterion=gini, max_depth=30, min_samples_leaf=50, min_samples_split=100, n_estimators=150;, score=0.851 total time=  26.9s
# [CV 3/3] END criterion=gini, max_depth=30, min_samples_leaf=50, min_samples_split=100, n_estimators=150;, score=0.821 total time=   5.9s
# [CV 1/3] END criterion=entropy, max_depth=50, min_samples_leaf=50, min_samples_split=400, n_estimators=500;, score=0.863 total time= 1.6min
# [CV 2/3] END criterion=entropy, max_depth=50, min_samples_leaf=50, min_samples_split=400, n_estimators=500;, score=0.857 total time= 1.6min
# [CV 3/3] END criterion=entropy, max_depth=50, min_samples_leaf=50, min_samples_split=400, n_estimators=500;, score=0.829 total time=  22.2s
# [CV 1/3] END criterion=log_loss, max_depth=20, min_samples_leaf=50, min_samples_split=50, n_estimators=200;, score=0.853 total time=  28.0s
# [CV 2/3] END criterion=log_loss, max_depth=20, min_samples_leaf=50, min_samples_split=50, n_estimators=200;, score=0.846 total time=  28.6s
# [CV 3/3] END criterion=log_loss, max_depth=20, min_samples_leaf=50, min_samples_split=50, n_estimators=200;, score=0.823 total time=   7.9s
# [CV 1/3] END criterion=entropy, max_depth=20, min_samples_leaf=100, min_samples_split=200, n_estimators=100;, score=0.844 total time=  12.6s
# [CV 2/3] END criterion=entropy, max_depth=20, min_samples_leaf=100, min_samples_split=200, n_estimators=100;, score=0.832 total time=  12.8s
# [CV 3/3] END criterion=entropy, max_depth=20, min_samples_leaf=100, min_samples_split=200, n_estimators=100;, score=0.802 total time=   3.2s
# [CV 1/3] END criterion=gini, max_depth=75, min_samples_leaf=100, min_samples_split=10, n_estimators=200;, score=0.852 total time=  30.2s
# [CV 2/3] END criterion=gini, max_depth=75, min_samples_leaf=100, min_samples_split=10, n_estimators=200;, score=0.843 total time=  31.4s
# [CV 3/3] END criterion=gini, max_depth=75, min_samples_leaf=100, min_samples_split=10, n_estimators=200;, score=0.810 total time=   8.4s

# %%
# best parameters
best_clf.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 100,
#  'min_samples_leaf': 25,
#  'max_depth': 100,
#  'criterion': 'log_loss'}

# %%
# highest accuracy score
best_clf.best_score_
# Out:
# 0.8586531118965618

# %% [markdown]
# Function to help us evaluate model performance

# %%
def train_and_eval(model, trainX, trainY, testX, testY):

    # training the model
    fitted_model = model.fit(trainX, trainY)

    # getting predictions
    y_preds_train = fitted_model.predict(trainX)
    y_preds_test = fitted_model.predict(testX)

    # evaluating the model
    print()
    print(model)
    print(f"Train accuracy score : {accuracy_score(trainY, y_preds_train)}")
    print(f"Test accuracy score : {accuracy_score(testY, y_preds_test)}")
    print(classification_report(testY, y_preds_test))
    print('\n',40*'-')

# %% [markdown]
# run below for this section, and edit accordingly

# %%
best_rf = RandomForestClassifier(
    random_state=42,
    n_estimators=200,
    min_samples_split=100,
    min_samples_leaf=25,
    max_depth=100,
    criterion='log_loss'
)

# %%
train_and_eval(best_rf, class2_bow_X_train, class2_y_train, class2_bow_X_test, class2_y_test)
# Out:
# RandomForestClassifier(criterion='log_loss', max_depth=100, min_samples_leaf=25,
#                        min_samples_split=100, n_estimators=200,
#                        random_state=42)
# Train accuracy score : 0.8809119535687824
# Test accuracy score : 0.8536931818181818
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.85      8096
#            1       0.84      0.87      0.86      8096
#
#     accuracy                           0.85     16192
#    macro avg       0.85      0.85      0.85     16192
# weighted avg       0.85      0.85      0.85     16192
#
#
#  ----------------------------------------

# %% [markdown]
# Best Random Forest model with BOW gave us 85.3% accuracy on test data

# %% [markdown]
# # Tuning Random Forest with TF-IDF

# %%
param_grid = {
    'n_estimators': [50, 100, 150, 200, 500, 1000],
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_depth': [20, 30, 50, 75, 100],
    'min_samples_split': [10, 25, 50, 100, 150, 200, 400],
    'min_samples_leaf': [25, 50, 100]
}

# %%
rf_model = RandomForestClassifier(random_state = 42, n_jobs = -1)
clf = RandomizedSearchCV(rf_model, param_distributions=param_grid, cv=3, verbose=4, scoring='accuracy', random_state=42, n_iter=20)

# %%
best_clf = clf.fit(class2_tfidf_X_train, class2_y_train)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV 1/3] END criterion=entropy, max_depth=100, min_samples_leaf=100, min_samples_split=200, n_estimators=100;, score=0.842 total time=  20.2s
# [CV 2/3] END criterion=entropy, max_depth=100, min_samples_leaf=100, min_samples_split=200, n_estimators=100;, score=0.842 total time=  19.4s
# [CV 3/3] END criterion=entropy, max_depth=100, min_samples_leaf=100, min_samples_split=200, n_estimators=100;, score=0.802 total time=   6.5s
# [CV 1/3] END criterion=entropy, max_depth=75, min_samples_leaf=50, min_samples_split=10, n_estimators=500;, score=0.860 total time= 2.0min
# [CV 2/3] END criterion=entropy, max_depth=75, min_samples_leaf=50, min_samples_split=10, n_estimators=500;, score=0.861 total time= 2.1min
# [CV 3/3] END criterion=entropy, max_depth=75, min_samples_leaf=50, min_samples_split=10, n_estimators=500;, score=0.828 total time=  35.1s
# [CV 1/3] END criterion=log_loss, max_depth=75, min_samples_leaf=100, min_samples_split=100, n_estimators=1000;, score=0.849 total time= 3.0min
# [CV 2/3] END criterion=log_loss, max_depth=75, min_samples_leaf=100, min_samples_split=100, n_estimators=1000;, score=0.851 total time= 3.3min
# [CV 3/3] END criterion=log_loss, max_depth=75, min_samples_leaf=100, min_samples_split=100, n_estimators=1000;, score=0.810 total time=  52.9s
# [CV 1/3] END criterion=log_loss, max_depth=100, min_samples_leaf=25, min_samples_split=100, n_estimators=200;, score=0.871 total time= 1.0min
# [CV 2/3] END criterion=log_loss, max_depth=100, min_samples_leaf=25, min_samples_split=100, n_estimators=200;, score=0.873 total time= 1.1min
# [CV 3/3] END criterion=log_loss, max_depth=100, min_samples_leaf=25, min_samples_split=100, n_estimators=200;, score=0.847 total time=  20.3s
# [CV 1/3] END criterion=log_loss, max_depth=30, min_samples_leaf=50, min_samples_split=200, n_estimators=200;, score=0.852 total time=  38.2s
# [CV 2/3] END criterion=log_loss, max_depth=30, min_samples_leaf=50, min_samples_split=200, n_estimators=200;, score=0.856 total time=  40.0s
# [CV 3/3] END criterion=log_loss, max_depth=30, min_samples_leaf=50, min_samples_split=200, n_estimators=200;, score=0.820 total time=  11.9s
# [CV 1/3] END criterion=log_loss, max_depth=75, min_samples_leaf=100, min_samples_split=25, n_estimators=50;, score=0.829 total time=   9.9s
# [CV 2/3] END criterion=log_loss, max_depth=75, min_samples_leaf=100, min_samples_split=25, n_estimators=50;, score=0.832 total time=  10.6s
# [CV 3/3] END criterion=log_loss, max_depth=75, min_samples_leaf=100, min_samples_split=25, n_estimators=50;, score=0.790 total time=   2.6s
# [CV 1/3] END criterion=gini, max_depth=100, min_samples_leaf=100, min_samples_split=25, n_estimators=150;, score=0.845 total time=  27.7s
# [CV 2/3] END criterion=gini, max_depth=100, min_samples_leaf=100, min_samples_split=25, n_estimators=150;, score=0.843 total time=  27.8s
# [CV 3/3] END criterion=gini, max_depth=100, min_samples_leaf=100, min_samples_split=25, n_estimators=150;, score=0.806 total time=   7.2s
# [CV 1/3] END criterion=log_loss, max_depth=100, min_samples_leaf=50, min_samples_split=25, n_estimators=50;, score=0.845 total time=  12.0s
# [CV 2/3] END criterion=log_loss, max_depth=100, min_samples_leaf=50, min_samples_split=25, n_estimators=50;, score=0.844 total time=  12.7s
# [CV 3/3] END criterion=log_loss, max_depth=100, min_samples_leaf=50, min_samples_split=25, n_estimators=50;, score=0.812 total time=   4.8s
# [CV 1/3] END criterion=entropy, max_depth=30, min_samples_leaf=100, min_samples_split=100, n_estimators=100;, score=0.842 total time=  17.1s
# [CV 2/3] END criterion=entropy, max_depth=30, min_samples_leaf=100, min_samples_split=100, n_estimators=100;, score=0.839 total time=  17.5s
# [CV 3/3] END criterion=entropy, max_depth=30, min_samples_leaf=100, min_samples_split=100, n_estimators=100;, score=0.803 total time=   5.8s
# [CV 1/3] END criterion=gini, max_depth=30, min_samples_leaf=100, min_samples_split=10, n_estimators=150;, score=0.842 total time=  24.1s
# [CV 2/3] END criterion=gini, max_depth=30, min_samples_leaf=100, min_samples_split=10, n_estimators=150;, score=0.842 total time=  25.9s
# [CV 3/3] END criterion=gini, max_depth=30, min_samples_leaf=100, min_samples_split=10, n_estimators=150;, score=0.807 total time=   8.0s
# [CV 1/3] END criterion=log_loss, max_depth=20, min_samples_leaf=50, min_samples_split=200, n_estimators=150;, score=0.846 total time=  22.6s
# [CV 2/3] END criterion=log_loss, max_depth=20, min_samples_leaf=50, min_samples_split=200, n_estimators=150;, score=0.848 total time=  23.1s
# [CV 3/3] END criterion=log_loss, max_depth=20, min_samples_leaf=50, min_samples_split=200, n_estimators=150;, score=0.814 total time=   8.2s
# [CV 1/3] END criterion=entropy, max_depth=20, min_samples_leaf=100, min_samples_split=25, n_estimators=100;, score=0.838 total time=  14.3s
# [CV 2/3] END criterion=entropy, max_depth=20, min_samples_leaf=100, min_samples_split=25, n_estimators=100;, score=0.833 total time=  14.6s
# [CV 3/3] END criterion=entropy, max_depth=20, min_samples_leaf=100, min_samples_split=25, n_estimators=100;, score=0.799 total time=   4.3s
# [CV 1/3] END criterion=gini, max_depth=50, min_samples_leaf=100, min_samples_split=50, n_estimators=500;, score=0.848 total time= 1.5min
# [CV 2/3] END criterion=gini, max_depth=50, min_samples_leaf=100, min_samples_split=50, n_estimators=500;, score=0.848 total time= 1.5min
# [CV 3/3] END criterion=gini, max_depth=50, min_samples_leaf=100, min_samples_split=50, n_estimators=500;, score=0.811 total time=  23.5s
# [CV 1/3] END criterion=gini, max_depth=100, min_samples_leaf=50, min_samples_split=200, n_estimators=50;, score=0.842 total time=  11.5s
# [CV 2/3] END criterion=gini, max_depth=100, min_samples_leaf=50, min_samples_split=200, n_estimators=50;, score=0.847 total time=  12.4s
# [CV 3/3] END criterion=gini, max_depth=100, min_samples_leaf=50, min_samples_split=200, n_estimators=50;, score=0.812 total time=   2.8s
# [CV 1/3] END criterion=log_loss, max_depth=100, min_samples_leaf=50, min_samples_split=100, n_estimators=50;, score=0.845 total time=  12.2s
# [CV 2/3] END criterion=log_loss, max_depth=100, min_samples_leaf=50, min_samples_split=100, n_estimators=50;, score=0.844 total time=  12.6s
# [CV 3/3] END criterion=log_loss, max_depth=100, min_samples_leaf=50, min_samples_split=100, n_estimators=50;, score=0.812 total time=   3.1s
# [CV 1/3] END criterion=gini, max_depth=30, min_samples_leaf=50, min_samples_split=100, n_estimators=150;, score=0.852 total time=  27.6s
# [CV 2/3] END criterion=gini, max_depth=30, min_samples_leaf=50, min_samples_split=100, n_estimators=150;, score=0.850 total time=  28.0s
# [CV 3/3] END criterion=gini, max_depth=30, min_samples_leaf=50, min_samples_split=100, n_estimators=150;, score=0.818 total time=   8.2s
# [CV 1/3] END criterion=entropy, max_depth=50, min_samples_leaf=50, min_samples_split=400, n_estimators=500;, score=0.858 total time= 1.8min
# [CV 2/3] END criterion=entropy, max_depth=50, min_samples_leaf=50, min_samples_split=400, n_estimators=500;, score=0.860 total time= 1.9min
# [CV 3/3] END criterion=entropy, max_depth=50, min_samples_leaf=50, min_samples_split=400, n_estimators=500;, score=0.827 total time=  30.1s
# [CV 1/3] END criterion=log_loss, max_depth=20, min_samples_leaf=50, min_samples_split=50, n_estimators=200;, score=0.848 total time=  29.2s
# [CV 2/3] END criterion=log_loss, max_depth=20, min_samples_leaf=50, min_samples_split=50, n_estimators=200;, score=0.852 total time=  30.8s
# [CV 3/3] END criterion=log_loss, max_depth=20, min_samples_leaf=50, min_samples_split=50, n_estimators=200;, score=0.811 total time=   8.8s
# [CV 1/3] END criterion=entropy, max_depth=20, min_samples_leaf=100, min_samples_split=200, n_estimators=100;, score=0.838 total time=  13.5s
# [CV 2/3] END criterion=entropy, max_depth=20, min_samples_leaf=100, min_samples_split=200, n_estimators=100;, score=0.833 total time=  13.9s
# [CV 3/3] END criterion=entropy, max_depth=20, min_samples_leaf=100, min_samples_split=200, n_estimators=100;, score=0.799 total time=   4.9s
# [CV 1/3] END criterion=gini, max_depth=75, min_samples_leaf=100, min_samples_split=10, n_estimators=200;, score=0.845 total time=  33.7s
# [CV 2/3] END criterion=gini, max_depth=75, min_samples_leaf=100, min_samples_split=10, n_estimators=200;, score=0.845 total time=  35.7s
# [CV 3/3] END criterion=gini, max_depth=75, min_samples_leaf=100, min_samples_split=10, n_estimators=200;, score=0.807 total time=   8.1s

# %%
# best parameters
best_clf.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 100,
#  'min_samples_leaf': 25,
#  'max_depth': 100,
#  'criterion': 'log_loss'}

# %%
# highest accuracy score
best_clf.best_score_
# Out:
# 0.8639785023136602

# %%
best_rf = RandomForestClassifier(
    random_state=42,
    n_estimators=200,
    min_samples_split=100,
    min_samples_leaf=25,
    max_depth=100,
    criterion='log_loss'
)

# %%
train_and_eval(best_rf, class2_tfidf_X_train, class2_y_train, class2_tfidf_X_test, class2_y_test)
# Out:
# RandomForestClassifier(criterion='log_loss', max_depth=100, min_samples_leaf=25,
#                        min_samples_split=100, n_estimators=200,
#                        random_state=42)
# Train accuracy score : 0.8982619165225981
# Test accuracy score : 0.8515316205533597
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85      8096
#            1       0.85      0.86      0.85      8096
#
#     accuracy                           0.85     16192
#    macro avg       0.85      0.85      0.85     16192
# weighted avg       0.85      0.85      0.85     16192
#
#
#  ----------------------------------------

# %% [markdown]
# Best Random forest Classifier with TF-IDF gives us 85.1% accuracy on test data
